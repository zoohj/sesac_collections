# %%
import requests
from pprint import pprint

URL = "https://api.themoviedb.org/3/movie/now_playing"
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYWI4Yzk4OTNlNzI1YjJlMTY3MTg3Y2VmNjZiYWUzZCIsIm5iZiI6MTYyNzYwODIyMC4xMzUsInN1YiI6IjYxMDM1NDljNGU1MmVkMDA3NTg3ZDhjYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oh38inWROms2MMFyhEFbbTs8qt3a1tOu_9m-56aQn8"


params = {
    'language' : 'ko-kr',
    # 'api_key' : "짧은 그 키"
}

headers = {
    "Authorization" : f"Bearer {API_KEY}"
}

try:
    response = requests.get(URL, headers=headers, params=params)

    response.raise_for_status()
    # if not response.status_code == 200:
    #     raise Exception
    
    data = response.json()

    data = data

    pprint(data)
    
except Exception as e:
    print(e)

# except requests.exceptions.HTTPError as errh:
#     print(f"Http Error: {errh}") # 401(인증오류), 404(경로오류) 등
# except requests.exceptions.ConnectionError as errc:
#     print(f"Error Connecting: {errc}") # 인터넷 연결 끊김
# except requests.exceptions.Timeout as errt:
#     print(f"Timeout Error: {errt}") # 서버 응답 지연
# except requests.exceptions.RequestException as err:
#     print(f"{err}") # 그 외 requests 관련 에러
# except ValueError:
#     print("JSON Decoding failed") # 응답이 JSON 형식이 아닐 때
# except Exception as e:
#     print(f"Unknown Error: {e}") # 정말 예상치 못한 일반 에러

# %% [markdown]
# ### 문제 1
# 현재 상영 중인 영화(Now Playing) 중 평점(vote_average)이 가장 높은 영화를 찾으시오.

# %%
import requests
from pprint import pprint

URL = "https://api.themoviedb.org/3/movie/now_playing"
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYWI4Yzk4OTNlNzI1YjJlMTY3MTg3Y2VmNjZiYWUzZCIsIm5iZiI6MTYyNzYwODIyMC4xMzUsInN1YiI6IjYxMDM1NDljNGU1MmVkMDA3NTg3ZDhjYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oh38inWROms2MMFyhEFbbTs8qt3a1tOu_9m-56aQn8"

params = {
    'language' : 'ko-kr',
    # 'api_key' : "짧은 그 키"
}

headers = {
    "Authorization" : f"Bearer {API_KEY}"
}

try:
    response = requests.get(URL, headers=headers, params=params)

    response.raise_for_status()
    # if not response.status_code == 200:
    #     raise Exception
    
    data = response.json()

    data = data['results']

    # [영화, 영화, 영화]

    max_vote_average = 0
    max_vote_average_movie = None

    for movie in data:
        # pprint(movie)
        title = movie['title']
        vote_average = movie['vote_average']
        # print(title, vote_average)
        if max_vote_average < vote_average:
            max_vote_average = vote_average
            max_vote_average_movie = title
    print(max_vote_average)
    print(max_vote_average_movie)
    
except Exception as e:
    print(e)

# %%
lst = [1, 5, 3, 7, 2, 9, 10]
# 최대값은 무엇이니?
max_num = 0
for num in lst:
    if max_num < num:
        max_num = num 
print(max_num)

lst = [{'num':1}, {'num':5}, {'num':3}]
# 최대값은 무엇이니?
max_num = 0
for dic in lst:
    num = dic['num']
    if max_num < num:
        max_num = num 
print(max_num)

# %% [markdown]
# ### 문제 2
# 인기있는 영화(Popular) 중 평점(vote_average)이 가장 높은 영화를 찾으시오.

# %%
import requests
from pprint import pprint

URL = "https://api.themoviedb.org/3/movie/popular"
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYWI4Yzk4OTNlNzI1YjJlMTY3MTg3Y2VmNjZiYWUzZCIsIm5iZiI6MTYyNzYwODIyMC4xMzUsInN1YiI6IjYxMDM1NDljNGU1MmVkMDA3NTg3ZDhjYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oh38inWROms2MMFyhEFbbTs8qt3a1tOu_9m-56aQn8"

params = {
    'language' : 'ko-kr',
    # 'api_key' : "짧은 그 키"
}

headers = {
    "Authorization" : f"Bearer {API_KEY}"
}

try:
    response = requests.get(URL, headers=headers, params=params)

    response.raise_for_status()
    # if not response.status_code == 200:
    #     raise Exception
    
    data = response.json()

    data = data['results']

    # [영화, 영화, 영화]

    
    def get_max_vote_average_movie(movies: list) -> dict:
        """
        영화들의 list를 입력받아서
        평점이 가장 높은 영화를 반환하는 함수.
        
        Args:
            movies : list - 영화에 대한 리스트
        """
        max_vote_average = 0
        max_vote_average_movie = None
        for movie in movies:
            
            vote_average = movie['vote_average']
            
            if max_vote_average < vote_average:
                max_vote_average = vote_average
                max_vote_average_movie = movie
        return max_vote_average_movie
    
    max_vote_average_movie = get_max_vote_average_movie(data)
    title = max_vote_average_movie['title']
    print(title)
    
except Exception as e:
    print(e)

# %% [markdown]
# ### 문제 3
# 현재 상영 중인 영화(now_playing) 데이터에서 다음 정보만 담긴 리스트를 만드세요.
#
# - title (영화 제목)
# - vote_average (평점)
# - release_date (개봉일)

# %%
# now_playing 영화 가져오는 함수
import requests
from pprint import pprint
def get_now_playing_movies():

    URL = "https://api.themoviedb.org/3/movie/now_playing"
    API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYWI4Yzk4OTNlNzI1YjJlMTY3MTg3Y2VmNjZiYWUzZCIsIm5iZiI6MTYyNzYwODIyMC4xMzUsInN1YiI6IjYxMDM1NDljNGU1MmVkMDA3NTg3ZDhjYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oh38inWROms2MMFyhEFbbTs8qt3a1tOu_9m-56aQn8"


    params = {
        'language' : 'ko-kr',
        # 'api_key' : "짧은 그 키"
    }

    headers = {
        "Authorization" : f"Bearer {API_KEY}"
    }
    try:
        response = requests.get(URL, headers=headers, params=params)
        response.raise_for_status()
        data = response.json()

        return data
        
    except Exception as e:
        print(e)

# %%
data = get_now_playing_movies()
# pprint(data)
movies = data['results']
simple_movies = []
for movie in movies:
    title = movie['title']
    vote_average = movie['vote_average']
    release_date = movie['release_date']
    simple_movie = {
        'title' : title,
        'vote_average' : vote_average,
        'release_date' : release_date
    }
    simple_movies.append(simple_movie)
pprint(simple_movies)

# %% [markdown]
# ### 문제 4
# 현재 상영 중인 영화(now_playing) 데이터를 vote_average(평점)순으로 정렬하여 영화 제목이 담긴 리스트를 만드세요.
# 단, 리스트의 길이는 100 이상이어야 합니다.

# %%
movies = []
for i in range(1, 6):
    data = get_movie_by_path("movie/now_playing", page=i)
    movies.extend(data['results'])
    # for movie in data['results']:
    #     movies.append(movie)

# pprint(movies)
# [{'vote_average' : 1}, {'vote_average' : 2}, {}]
movies.sort(key = lambda x : x['vote_average'], reverse=True)

pprint([(m['title'], m['vote_average']) for m in movies])

# %%
# 정렬

# %% [markdown]
# ### 문제 5
# 현재 상영 중인 영화 중 평점(vote_average)이 가장 높은 영화의 수익(revenue)를 찾으시오.
# hint) API 문서의 endpoint 항목을 참고하세요.

# %%
# 1. 현재 상영중인 영화를 가져온다.
# 2. 평점이 가장 높은 영화를 찾는다.
# 3. id를 찾는다.
# 4. 새로운 api (detail)에 요청을 보낸다.
# 5. revenue를 찾는다.

# 1. 현재 상영중인 영화를 가져온다.
data = get_now_playing_movies()
movies = data['results']

# 2. 평점이 가장 높은 영화를 찾는다.
max_vote_average_movie = get_max_vote_average_movie(movies)

# 3. id를 찾는다.
movie_id = max_vote_average_movie['id']
print(movie_id)

URL = f"https://api.themoviedb.org/3/movie/{movie_id}"
API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYWI4Yzk4OTNlNzI1YjJlMTY3MTg3Y2VmNjZiYWUzZCIsIm5iZiI6MTYyNzYwODIyMC4xMzUsInN1YiI6IjYxMDM1NDljNGU1MmVkMDA3NTg3ZDhjYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oh38inWROms2MMFyhEFbbTs8qt3a1tOu_9m-56aQn8"


params = {
    'language' : 'ko-kr',
    # 'api_key' : "짧은 그 키"
}

headers = {
    "Authorization" : f"Bearer {API_KEY}"
}

try:
    response = requests.get(URL, headers=headers, params=params)

    response.raise_for_status()
    # if not response.status_code == 200:
    #     raise Exception
    
    movie = response.json()

    revenue = movie['revenue']
    print('title', movie['title'])
    print('revenue', revenue)
    
    
except Exception as e:
    print(e)

# %% [markdown]
# ### 문제 6
# 현재 상영 중인 영화 중 평점(vote_average)이 가장 높은 영화의 포스터 이미지를 조회하시오.
# hint) API 문서의 `Guides`를 참고하세요

# %%
# 1. 현재 상영중인 영화를 가져온다.
data = get_now_playing_movies()
movies = data['results']

# 2. 평점이 가장 높은 영화를 찾는다.
max_vote_average_movie = get_max_vote_average_movie(movies)

pprint(max_vote_average_movie)

# api 문서를 뒤지면, https://image.tmdb.org/t/p/w500/과 같은 URL을 얻을 수 있다.
# 여기에 poster_path를 붙이면 된다.

# %% [markdown]
# ### 문제 7
# 현재 상영 중인 영화 중 평점(vote_average)이 가장 높은 영화의 배우(Credit / cast) 정보를 조회하시오.
# hint) API 문서의 endpoint 항목을 참고하세요

# %%
# 1. 현재 상영중인 영화를 가져온다.
data = get_now_playing_movies()
movies = data['results']

# 2. 평점이 가장 높은 영화를 찾는다.
max_vote_average_movie = get_max_vote_average_movie(movies)

movie_id = max_vote_average_movie['id']

def get_movie_by_path(path):

    URL = f"https://api.themoviedb.org/3/{path}"

    API_KEY = "eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiJlYWI4Yzk4OTNlNzI1YjJlMTY3MTg3Y2VmNjZiYWUzZCIsIm5iZiI6MTYyNzYwODIyMC4xMzUsInN1YiI6IjYxMDM1NDljNGU1MmVkMDA3NTg3ZDhjYiIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.7oh38inWROms2MMFyhEFbbTs8qt3a1tOu_9m-56aQn8"
    params = {
        'language' : 'ko-kr',
        # 'api_key' : "짧은 그 키"
    }

    headers = {
        "Authorization" : f"Bearer {API_KEY}"
    }
    data = requests.get(URL, headers=headers, params=params)
    return data.json()

data = get_movie_by_path(f"movie/{movie_id}/credits")
# get_movie_by_path(f"movie/now_playing")
# get_movie_by_path(f"movie/{movie_id}")
actors = data['cast']
print(len(actors))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # 1. 현재 상영중인 영화를 가져온다.
# ----> 2 data = get_now_playing_movies()
#       3 movies = data['results']
#       5 # 2. 평점이 가장 높은 영화를 찾는다.
#
# NameError: name 'get_now_playing_movies' is not defined

# %% [markdown]
# ### 문제 8
# 현재 상영 중인 영화(now_playing) 데이터에서 다음 정보만 담긴 리스트를 만드세요.
# 단, 장르는 text로 이루어진 list입니다.
#
# - title (영화 제목)
# - genres (장르)
#
# hint) API 문서의 endpoint 항목을 참고하세요

# %%
data = get_movie_by_path(f"movie/now_playing")
movies = data['results']

genres_data = get_movie_by_path(f"genre/movie/list")
genres_data = genres_data['genres']
count = 1
for movie in movies:
    title = movie['title']
    genres = movie['genre_ids']
    genres_lst = []
    for id in genres:
        for genre in genres_data:
            count += 1
            if id == genre['id']:
                genres_lst.append(genre['name'])
                # break

    # print(title, genres_lst)

print(count)

# %%
data = get_movie_by_path(f"movie/now_playing")
movies = data['results']

genres_data = get_movie_by_path(f"genre/movie/list")
genres_data = genres_data['genres']
pprint(genres_data)

genres_dict = {
    # id : name
}

count = 1
for genre in genres_data:
    count += 1
    id = genre['id']
    name = genre['name']
    genres_dict[id] = name
pprint(genres_dict)



for movie in movies:
    title = movie['title']
    genres = movie['genre_ids']
    genres_lst = []
    for id in genres:
        count += 1
        genre_name = genres_dict[id]
        genres_lst.append(genre_name)

    print(title, genres_lst)

print(count)
