# %% [markdown]
# # problem06

# %%
scores = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78,
    "David": 95,
    "Eve": 88
}

# %% [markdown]
# ---
# ### 문제 1
# `scores` 딕셔너리에 있는 모든 학생의 이름을 한 줄에 하나씩 출력하세요.

# %%
# 코드를 여기에 작성하세요

for name in scores:
    print(name)

for name in scores.keys():
    print(name)
# Out:
# Alice
# Bob
# Charlie
# David
# Eve
# Alice
# Bob
# Charlie
# David
# Eve

# %% [markdown]
# ### 문제 2
# `scores` 딕셔너리의 모든 점수를 더하여 총합을 출력하세요.

# %%
# 코드를 여기에 작성하세요
total = 0
for key in scores:
    value = scores[key]
    total += value
print(total)

print(sum(scores.values()))
# Out:
# 438
# 438

# %% [markdown]
# ### 문제 3
# 모든 학생의 이름과 점수를 `Alice : 85` 와 같은 형식으로 출력하세요.

# %%
# 코드를 여기에 작성하세요

for key in scores:
    value = scores[key]
    print(f"{key} : {value}")
# Out:
# Alice : 85
# Bob : 92
# Charlie : 78
# David : 95
# Eve : 88

# %%
templates = "이름 : {} / 점수 : {}"

for key in scores:
    value = scores[key]
    print(templates.format(key, value))
# Out:
# 이름 : Alice / 점수 : 85
# 이름 : Bob / 점수 : 92
# 이름 : Charlie / 점수 : 78
# 이름 : David / 점수 : 95
# 이름 : Eve / 점수 : 88

# %%
templates = "이름 : {name} / 점수 : {score}"

for name in scores:
    score = scores[name]
    print(templates.format(name=name, score=score))
# Out:
# 이름 : Alice / 점수 : 85
# 이름 : Bob / 점수 : 92
# 이름 : Charlie / 점수 : 78
# 이름 : David / 점수 : 95
# 이름 : Eve / 점수 : 88

# %% [markdown]
# ### 문제 4
# 점수가 90점 이상인 '우수 학생'의 명단을 리스트 형식으로 만들어 출력하세요.

# %%
# 코드를 여기에 작성하세요
# 1. 학생들의 점수를 확인해야 합니다.
# 2. 90점 이상인지 확인합니다
# 3. 명단의 list를 만듭니다 (즉, value뿐만 아니라 name도 필요합니다)

good_student = []
for name, socore in score.items()

good_list = []
for name, score in scores.items():
    if score >= 90:
        good_list.append(name)
print(good_list)
# Out:
# ['Bob', 'David']

# %%
# 나에게 good_list가 있어. 근데 기준은 몰라. good_list에 없는 학생을 어떻게 판단하지?
# not in
# set() 전체 - goodlist(차집합) => 없는 사람이 나옴.

for name in scores.keys():
    if name not in good_list:
        print(f'{name} good list에 없어')
        
print(set(scores.keys()) - set(good_list))
# Out:
# Alice good list에 없어
# Charlie good list에 없어
# Eve good list에 없어
# {'Alice', 'Eve', 'Charlie'}

# %% [markdown]
# ### 문제 5
# 기존 `scores` 딕셔너리를 사용하여, 점수가 80점 이상이면 'Pass', 미만이면 'Fail'을 값으로 가지는 새로운 딕셔너리를 만드세요.

# %%
# 코드를 여기에 작성하세요
# 결과는
# {
#     이름1 : pass,
#     이름2 : fail
# }


scores = {
    "Alice": 85,
    "Bob": 92,
    "Charlie": 78,
    "David": 95,
    "Eve": 88
}

students = {}

for name, score in scores.items():
    if score >= 80:
        students[name] = 'pass'
    else:
        students[name] = 'fail'
print(students)
# Out:
# result={'Alice': 'pass', 'Bob': 'pass', 'Charlie': 'fail', 'David': 'pass', 'Eve': 'pass'}
# {'Alice': 'pass', 'Bob': 'pass', 'Charlie': 'fail', 'David': 'pass', 'Eve': 'pass'}

# %%
students = {}
good_score = 80

for name, score in scores.items():
    status = None

    if score >= good_score:
        status = 'pass'
    else:
        status = 'fail'
    
    students[name] = status
# print(students)
# Out:
# {'Alice': 'pass', 'Bob': 'pass', 'Charlie': 'fail', 'David': 'pass', 'Eve': 'pass'}

# %%
dic = {}

dic['a'] = 100

dic['a'] = 200
print(dic)
# Out:
# {'a': 200}
